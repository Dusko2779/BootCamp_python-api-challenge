# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lautoka
# Processing Record 2 of Set 1 | qaqortoq
# Processing Record 3 of Set 1 | rice lake
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | ishigaki
# Processing Record 6 of Set 1 | tazacorte
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | bilibino
# Processing Record 9 of Set 1 | reggane
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 1 | coquimbo
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | margaret river
# Processing Record 15 of Set 1 | olonkinbyen
# Processing Record 16 of Set 1 | rio grande
# Processing Record 17 of Set 1 | antofagasta
# Processing Record 18 of Set 1 | weiser
# Processing Record 19 of Set 1 | kone
# Processing Record 20 of Set 1 | gazli
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | yuzhno-kurilsk
# Processing Record 23 of Set 1 | vadso
# Processing Record 24 of Set 1 | adamstown
# Processing Record 25 of Set 1 | broome
# Processing Record 26 of Set 1 | we
# City not found. Skipping...
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | mount pearl
# Processing Record 30 of Set 1 | agustin codazzi
# Processing Record 31 of Set 1 | harper
# Processing Record 32 of Set 1 | waitangi
# Processing Record 33 of Set 1 | vilyuchinsk
# Processing Record 34 of Set 1 | savanna-la-mar
# Processing Record 35 of Set 1 | kozhevnikovo
# Processing Record 36 of Set 1 | weinzierl bei krems
# Processing Record 37 of Set 1 | mossel bay
# Processing Record 38 of Set 1 | eyl
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | invercargill
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | tolanaro
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | lazaro cardenas
# Processing Record 45 of Set 1 | yamada
# Processing Record 46 of Set 1 | belokurikha
# Processing Record 47 of Set 1 | al mindak
# Processing Record 48 of Set 1 | kapuskasing
# Processing Record 49 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 50 of Set 1 | kodiak
# Processing Record 0 of Set 2 | hadibu
# Processing Record 1 of Set 2 | clodomira
# Processing Record 2 of Set 2 | edinburgh of the seven seas
# Processing Record 3 of Set 2 | kristiansund
# Processing Record 4 of Set 2 | puerto natales
# Processing Record 5 of Set 2 | walvis bay
# Processing Record 6 of Set 2 | fort bragg
# Processing Record 7 of Set 2 | benghazi
# Processing Record 8 of Set 2 | zafarwal
# Processing Record 9 of Set 2 | teguise
# Processing Record 10 of Set 2 | carentan
# Processing Record 11 of Set 2 | plettenberg bay
# Processing Record 12 of Set 2 | chaplynka
# Processing Record 13 of Set 2 | la celle-saint-cloud
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | tindouf
# Processing Record 16 of Set 2 | isle of lewis
# City not found. Skipping...
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | soio
# Processing Record 19 of Set 2 | kayangel
# Processing Record 20 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 21 of Set 2 | blackmans bay
# Processing Record 22 of Set 2 | pandan
# Processing Record 23 of Set 2 | west island
# Processing Record 24 of Set 2 | saint-francois
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | ain beni mathar
# City not found. Skipping...
# Processing Record 27 of Set 2 | aykhal
# Processing Record 28 of Set 2 | naze
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | stanley
# Processing Record 31 of Set 2 | namdrik
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | dudinka
# Processing Record 34 of Set 2 | buala
# Processing Record 35 of Set 2 | avellaneda
# Processing Record 36 of Set 2 | tazovsky
# Processing Record 37 of Set 2 | tsiombe
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | myeik
# Processing Record 40 of Set 2 | fiambala
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | mabaruma
# Processing Record 43 of Set 2 | quartu sant'elena
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | minas de marcona
# Processing Record 46 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | khovd
# Processing Record 49 of Set 2 | limon
# Processing Record 0 of Set 3 | westport
# Processing Record 1 of Set 3 | gizo
# Processing Record 2 of Set 3 | tutoia
# Processing Record 3 of Set 3 | yarrawonga
# Processing Record 4 of Set 3 | konosha
# Processing Record 5 of Set 3 | whitehorse
# Processing Record 6 of Set 3 | hotan
# Processing Record 7 of Set 3 | grojec
# Processing Record 8 of Set 3 | chibougamau
# Processing Record 9 of Set 3 | tuburan
# Processing Record 10 of Set 3 | cururupu
# Processing Record 11 of Set 3 | anadyr
# Processing Record 12 of Set 3 | laguna
# Processing Record 13 of Set 3 | gaziantep
# Processing Record 14 of Set 3 | maceio
# Processing Record 15 of Set 3 | pucallpa
# Processing Record 16 of Set 3 | angra do heroismo
# Processing Record 17 of Set 3 | fada
# Processing Record 18 of Set 3 | rongelap
# Processing Record 19 of Set 3 | luganville
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | fedorovskiy
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | papatowai
# Processing Record 24 of Set 3 | kangundo
# Processing Record 25 of Set 3 | wailua homesteads
# Processing Record 26 of Set 3 | lompoc
# Processing Record 27 of Set 3 | christchurch
# Processing Record 28 of Set 3 | labrador city
# Processing Record 29 of Set 3 | nakamura
# Processing Record 30 of Set 3 | santa ana
# Processing Record 31 of Set 3 | isafjordur
# Processing Record 32 of Set 3 | lihue
# Processing Record 33 of Set 3 | safford
# Processing Record 34 of Set 3 | vila franca do campo
# Processing Record 35 of Set 3 | polyarnyy
# Processing Record 36 of Set 3 | dili
# Processing Record 37 of Set 3 | qaisumah
# Processing Record 38 of Set 3 | manokwari
# Processing Record 39 of Set 3 | siniscola
# Processing Record 40 of Set 3 | puqi
# Processing Record 41 of Set 3 | antanifotsy
# Processing Record 42 of Set 3 | santa cruz
# Processing Record 43 of Set 3 | phanat nikhom
# Processing Record 44 of Set 3 | college
# Processing Record 45 of Set 3 | swakopmund
# Processing Record 46 of Set 3 | khandyga
# Processing Record 47 of Set 3 | palmer
# Processing Record 48 of Set 3 | cooma
# Processing Record 49 of Set 3 | colonia
# Processing Record 0 of Set 4 | hengshui
# Processing Record 1 of Set 4 | semenivka
# Processing Record 2 of Set 4 | cockburn town
# Processing Record 3 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 4 of Set 4 | taoudenni
# Processing Record 5 of Set 4 | 'ali al gharbi
# Processing Record 6 of Set 4 | pangoa
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | kismayo
# Processing Record 9 of Set 4 | mejit
# Processing Record 10 of Set 4 | belmonte
# Processing Record 11 of Set 4 | nelson bay
# Processing Record 12 of Set 4 | karoi
# Processing Record 13 of Set 4 | badger
# Processing Record 14 of Set 4 | ouricuri
# Processing Record 15 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 4 | sorong
# Processing Record 17 of Set 4 | colares
# Processing Record 18 of Set 4 | magadan
# Processing Record 19 of Set 4 | lokomotivnyy
# Processing Record 20 of Set 4 | yeosu
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | st. john's
# Processing Record 24 of Set 4 | saint-pierre
# Processing Record 25 of Set 4 | petropavlovka
# Processing Record 26 of Set 4 | marquette
# Processing Record 27 of Set 4 | hawaiian paradise park
# Processing Record 28 of Set 4 | queenstown
# Processing Record 29 of Set 4 | tual
# Processing Record 30 of Set 4 | harstad
# Processing Record 31 of Set 4 | talitsy
# Processing Record 32 of Set 4 | qoryooley
# Processing Record 33 of Set 4 | thinadhoo
# Processing Record 34 of Set 4 | camiri
# Processing Record 35 of Set 4 | vakarai
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | crane
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | ulanhot
# Processing Record 40 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 41 of Set 4 | punta arenas
# Processing Record 42 of Set 4 | yagry
# City not found. Skipping...
# Processing Record 43 of Set 4 | solok
# Processing Record 44 of Set 4 | chinu
# Processing Record 45 of Set 4 | sanjwal
# Processing Record 46 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 47 of Set 4 | port mathurin
# Processing Record 48 of Set 4 | nagqu
# Processing Record 49 of Set 4 | kabansk
# Processing Record 0 of Set 5 | soanindrariny
# City not found. Skipping...
# Processing Record 1 of Set 5 | rio san juan
# Processing Record 2 of Set 5 | rabo de peixe
# Processing Record 3 of Set 5 | sisimiut
# Processing Record 4 of Set 5 | nova sintra
# Processing Record 5 of Set 5 | usinsk
# Processing Record 6 of Set 5 | la gi
# Processing Record 7 of Set 5 | ibiza
# Processing Record 8 of Set 5 | udachny
# Processing Record 9 of Set 5 | klyuchi
# Processing Record 10 of Set 5 | racine
# Processing Record 11 of Set 5 | rajula
# Processing Record 12 of Set 5 | hue
# Processing Record 13 of Set 5 | tadine
# Processing Record 14 of Set 5 | zhangjiakou
# Processing Record 15 of Set 5 | labytnangi
# Processing Record 16 of Set 5 | victorica
# Processing Record 17 of Set 5 | katsuren-haebaru
# Processing Record 18 of Set 5 | sur
# Processing Record 19 of Set 5 | chinde
# Processing Record 20 of Set 5 | machakos
# Processing Record 21 of Set 5 | las terrenas
# Processing Record 22 of Set 5 | ulsteinvik
# Processing Record 23 of Set 5 | atafu village
# Processing Record 24 of Set 5 | galliano
# Processing Record 25 of Set 5 | mhamid
# Processing Record 26 of Set 5 | bangassou
# Processing Record 27 of Set 5 | betio village
# Processing Record 28 of Set 5 | isle of arran
# City not found. Skipping...
# Processing Record 29 of Set 5 | san rafael
# Processing Record 30 of Set 5 | mayya
# Processing Record 31 of Set 5 | bantay
# Processing Record 32 of Set 5 | puerto armuelles
# Processing Record 33 of Set 5 | yssingeaux
# Processing Record 34 of Set 5 | opuwo
# Processing Record 35 of Set 5 | kolonia
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | amos
# Processing Record 38 of Set 5 | coahuayana de hidalgo
# Processing Record 39 of Set 5 | port pirie
# Processing Record 40 of Set 5 | san jose del guaviare
# Processing Record 41 of Set 5 | sumbe
# Processing Record 42 of Set 5 | awjilah
# Processing Record 43 of Set 5 | lata
# Processing Record 44 of Set 5 | gadzhiyevo
# Processing Record 45 of Set 5 | jequie
# Processing Record 46 of Set 5 | bestobe
# Processing Record 47 of Set 5 | kasongo-lunda
# Processing Record 48 of Set 5 | lembar
# City not found. Skipping...
# Processing Record 49 of Set 5 | saudarkrokur
# Processing Record 0 of Set 6 | fortuna
# Processing Record 1 of Set 6 | aasiaat
# Processing Record 2 of Set 6 | ouellah
# City not found. Skipping...
# Processing Record 3 of Set 6 | kayyerkan
# Processing Record 4 of Set 6 | carnarvon
# Processing Record 5 of Set 6 | arraial do cabo
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | san andres
# Processing Record 8 of Set 6 | afaahiti
# Processing Record 9 of Set 6 | san luis de la loma
# Processing Record 10 of Set 6 | the pas
# Processing Record 11 of Set 6 | kincardine
# Processing Record 12 of Set 6 | port isabel
# Processing Record 13 of Set 6 | pachino
# Processing Record 14 of Set 6 | ust-nera
# Processing Record 15 of Set 6 | praia da vitoria
# Processing Record 16 of Set 6 | thayetmyo
# Processing Record 17 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 18 of Set 6 | utrik
# Processing Record 19 of Set 6 | fort st. john
# Processing Record 20 of Set 6 | miri
# Processing Record 21 of Set 6 | ceerigaabo
# Processing Record 22 of Set 6 | jieshi
# Processing Record 23 of Set 6 | comandante fontana
# Processing Record 24 of Set 6 | iskateley
# Processing Record 25 of Set 6 | saint croix
# Processing Record 26 of Set 6 | dakhla
# Processing Record 27 of Set 6 | susuman
# Processing Record 28 of Set 6 | prado
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | balykshi
# Processing Record 31 of Set 6 | ciudad barrios
# Processing Record 32 of Set 6 | novodvinsk
# Processing Record 33 of Set 6 | patur
# Processing Record 34 of Set 6 | orchha
# Processing Record 35 of Set 6 | chernyshevsk
# Processing Record 36 of Set 6 | yeniseysk
# Processing Record 37 of Set 6 | al kut
# Processing Record 38 of Set 6 | mulayjah
# Processing Record 39 of Set 6 | hami
# Processing Record 40 of Set 6 | takoradi
# Processing Record 41 of Set 6 | nemuro
# Processing Record 42 of Set 6 | puerto baquerizo moreno
# Processing Record 43 of Set 6 | saldanha
# Processing Record 44 of Set 6 | floro
# Processing Record 45 of Set 6 | vila velha
# Processing Record 46 of Set 6 | kabo
# Processing Record 47 of Set 6 | bonthe
# Processing Record 48 of Set 6 | portland
# Processing Record 49 of Set 6 | laojunmiao
# Processing Record 0 of Set 7 | wattegama
# Processing Record 1 of Set 7 | el sauzal de rodriguez
# Processing Record 2 of Set 7 | alpine
# Processing Record 3 of Set 7 | ciudad lazaro cardenas
# Processing Record 4 of Set 7 | suntar
# Processing Record 5 of Set 7 | quelimane
# Processing Record 6 of Set 7 | bubaque
# Processing Record 7 of Set 7 | kingaroy
# Processing Record 8 of Set 7 | san patricio
# Processing Record 9 of Set 7 | xai-xai
# Processing Record 10 of Set 7 | mount gambier
# Processing Record 11 of Set 7 | quibdo
# Processing Record 12 of Set 7 | castillos
# Processing Record 13 of Set 7 | cadale
# Processing Record 14 of Set 7 | talcahuano
# Processing Record 15 of Set 7 | jayapura
# Processing Record 16 of Set 7 | constantia
# Processing Record 17 of Set 7 | kathmandu
# Processing Record 18 of Set 7 | itoman
# Processing Record 19 of Set 7 | san antonio de pale
# Processing Record 20 of Set 7 | buncrana
# Processing Record 21 of Set 7 | brookings
# Processing Record 22 of Set 7 | mukah
# City not found. Skipping...
# Processing Record 23 of Set 7 | flin flon
# Processing Record 24 of Set 7 | jennings
# Processing Record 25 of Set 7 | kahuta
# Processing Record 26 of Set 7 | ust'-ilimsk
# Processing Record 27 of Set 7 | gerash
# Processing Record 28 of Set 7 | shubarshi
# Processing Record 29 of Set 7 | orsta
# Processing Record 30 of Set 7 | peterhead
# Processing Record 31 of Set 7 | sangju
# Processing Record 32 of Set 7 | dahab
# Processing Record 33 of Set 7 | makhambet
# Processing Record 34 of Set 7 | rio brilhante
# Processing Record 35 of Set 7 | horta
# Processing Record 36 of Set 7 | geraldton
# Processing Record 37 of Set 7 | kuqa
# Processing Record 38 of Set 7 | hammerfest
# Processing Record 39 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 7 | hithadhoo
# Processing Record 41 of Set 7 | tvoroyri
# Processing Record 42 of Set 7 | cabedelo
# Processing Record 43 of Set 7 | masons bay
# City not found. Skipping...
# Processing Record 44 of Set 7 | pacifica
# Processing Record 45 of Set 7 | takab
# Processing Record 46 of Set 7 | mahibadhoo
# Processing Record 47 of Set 7 | nova xavantina
# Processing Record 48 of Set 7 | kruisfontein
# Processing Record 49 of Set 7 | fuerte olimpo
# Processing Record 0 of Set 8 | enoch
# Processing Record 1 of Set 8 | izazi
# Processing Record 2 of Set 8 | ambovombe
# Processing Record 3 of Set 8 | tofol
# Processing Record 4 of Set 8 | jaguaribe
# Processing Record 5 of Set 8 | rikaze
# Processing Record 6 of Set 8 | palanga
# Processing Record 7 of Set 8 | lisakovsk
# Processing Record 8 of Set 8 | muzayri'
# City not found. Skipping...
# Processing Record 9 of Set 8 | merizo village
# Processing Record 10 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 11 of Set 8 | kisangani
# Processing Record 12 of Set 8 | mugia
# Processing Record 13 of Set 8 | am djarass
# City not found. Skipping...
# Processing Record 14 of Set 8 | elva
# Processing Record 15 of Set 8 | mana
# Processing Record 16 of Set 8 | longyearbyen
# Processing Record 17 of Set 8 | ghat
# Processing Record 18 of Set 8 | sabang
# Processing Record 19 of Set 8 | formosa do rio preto
# Processing Record 20 of Set 8 | murzuq
# Processing Record 21 of Set 8 | port saint john's
# Processing Record 22 of Set 8 | tainan
# Processing Record 23 of Set 8 | egilsstadir
# Processing Record 24 of Set 8 | grand island
# Processing Record 25 of Set 8 | dunedin
# Processing Record 26 of Set 8 | pacific grove
# Processing Record 27 of Set 8 | eaglehawk
# Processing Record 28 of Set 8 | sao jose
# Processing Record 29 of Set 8 | enewetak
# Processing Record 30 of Set 8 | chanika
# Processing Record 31 of Set 8 | prainha
# Processing Record 32 of Set 8 | vorgashor
# Processing Record 33 of Set 8 | nuuk
# Processing Record 34 of Set 8 | morinville
# Processing Record 35 of Set 8 | sitka
# Processing Record 36 of Set 8 | almeirim
# Processing Record 37 of Set 8 | bode saadu
# Processing Record 38 of Set 8 | pisco
# Processing Record 39 of Set 8 | tevriz
# Processing Record 40 of Set 8 | izberbash
# Processing Record 41 of Set 8 | hachenburg
# Processing Record 42 of Set 8 | linxia chengguanzhen
# Processing Record 43 of Set 8 | navasota
# Processing Record 44 of Set 8 | gobabis
# Processing Record 45 of Set 8 | vernon
# Processing Record 46 of Set 8 | huangmei
# Processing Record 47 of Set 8 | el granada
# Processing Record 48 of Set 8 | hoxtolgay
# City not found. Skipping...
# Processing Record 49 of Set 8 | yanchep
# Processing Record 0 of Set 9 | al ghayzah
# Processing Record 1 of Set 9 | isangel
# Processing Record 2 of Set 9 | pacocha
# Processing Record 3 of Set 9 | weihai
# Processing Record 4 of Set 9 | irtyshsk
# Processing Record 5 of Set 9 | dabrowa bialostocka
# Processing Record 6 of Set 9 | georgievka
# Processing Record 7 of Set 9 | hafar al-batin
# Processing Record 8 of Set 9 | hamilton
# Processing Record 9 of Set 9 | dayr hafir
# Processing Record 10 of Set 9 | baijiantan
# Processing Record 11 of Set 9 | kokofata
# City not found. Skipping...
# Processing Record 12 of Set 9 | wellington
# Processing Record 13 of Set 9 | la ronge
# Processing Record 14 of Set 9 | codrington
# Processing Record 15 of Set 9 | fisterra
# Processing Record 16 of Set 9 | st. paul
# Processing Record 17 of Set 9 | sibut
# Processing Record 18 of Set 9 | vorkuta
# Processing Record 19 of Set 9 | al mijlad
# Processing Record 20 of Set 9 | ba
# City not found. Skipping...
# Processing Record 21 of Set 9 | sinabang
# Processing Record 22 of Set 9 | southeast arcadia
# Processing Record 23 of Set 9 | guerrero negro
# Processing Record 24 of Set 9 | necochea
# Processing Record 25 of Set 9 | north kingstown
# Processing Record 26 of Set 9 | hauterive
# Processing Record 27 of Set 9 | trogir
# Processing Record 28 of Set 9 | puerto madryn
# Processing Record 29 of Set 9 | rio preto da eva
# Processing Record 30 of Set 9 | kitimat
# Processing Record 31 of Set 9 | visakhapatnam
# Processing Record 32 of Set 9 | ambon
# Processing Record 33 of Set 9 | neman
# Processing Record 34 of Set 9 | port lincoln
# Processing Record 35 of Set 9 | warman
# Processing Record 36 of Set 9 | sao gabriel da cachoeira
# Processing Record 37 of Set 9 | gaspe
# Processing Record 38 of Set 9 | iwanai
# Processing Record 39 of Set 9 | tralee
# Processing Record 40 of Set 9 | selkirk
# Processing Record 41 of Set 9 | ambahta
# Processing Record 42 of Set 9 | bamboo flat
# Processing Record 43 of Set 9 | puerto santander
# Processing Record 44 of Set 9 | shagonar
# Processing Record 45 of Set 9 | redencao
# Processing Record 46 of Set 9 | nar'yan-mar
# Processing Record 47 of Set 9 | sharan
# Processing Record 48 of Set 9 | richards bay
# Processing Record 49 of Set 9 | auce
# Processing Record 0 of Set 10 | varzea da palma
# Processing Record 1 of Set 10 | dumas
# Processing Record 2 of Set 10 | kavaratti
# Processing Record 3 of Set 10 | kovalam
# Processing Record 4 of Set 10 | piqua
# Processing Record 5 of Set 10 | buchrain
# Processing Record 6 of Set 10 | salamanca
# Processing Record 7 of Set 10 | ndola
# Processing Record 8 of Set 10 | sungai penuh
# Processing Record 9 of Set 10 | james island
# City not found. Skipping...
# Processing Record 10 of Set 10 | harrismith
# Processing Record 11 of Set 10 | tynda
# Processing Record 12 of Set 10 | greymouth
# Processing Record 13 of Set 10 | novo aripuana
# Processing Record 14 of Set 10 | talara
# Processing Record 15 of Set 10 | lae
# Processing Record 16 of Set 10 | argo
# Processing Record 17 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 18 of Set 10 | kapa'a
# Processing Record 19 of Set 10 | wanganui
# Processing Record 20 of Set 10 | uturoa
# Processing Record 21 of Set 10 | ca mau
# Processing Record 22 of Set 10 | mizdah
# Processing Record 23 of Set 10 | xilin hot
# Processing Record 24 of Set 10 | loma de cabrera
# Processing Record 25 of Set 10 | kingston
# Processing Record 26 of Set 10 | port douglas
# Processing Record 27 of Set 10 | kailua-kona
# Processing Record 28 of Set 10 | mosjoen
# Processing Record 29 of Set 10 | howard springs
# Processing Record 30 of Set 10 | east london
# Processing Record 31 of Set 10 | touros
# Processing Record 32 of Set 10 | north battleford
# Processing Record 33 of Set 10 | tyrnyauz
# Processing Record 34 of Set 10 | loyew
# Processing Record 35 of Set 10 | paita
# Processing Record 36 of Set 10 | priozersk
# Processing Record 37 of Set 10 | suai
# City not found. Skipping...
# Processing Record 38 of Set 10 | riviere-du-loup
# Processing Record 39 of Set 10 | taro
# Processing Record 40 of Set 10 | sao vicente
# Processing Record 41 of Set 10 | tamanrasset
# Processing Record 42 of Set 10 | xianshuigu
# Processing Record 43 of Set 10 | magistral'nyy
# Processing Record 44 of Set 10 | tangalle
# Processing Record 45 of Set 10 | barmer
# Processing Record 46 of Set 10 | idrinskoye
# Processing Record 47 of Set 10 | severo-yeniseyskiy
# Processing Record 48 of Set 10 | cill airne
# Processing Record 49 of Set 10 | meadow lakes
# Processing Record 0 of Set 11 | ribeira brava
# Processing Record 1 of Set 11 | hanumangarh
# Processing Record 2 of Set 11 | flying fish cove
# Processing Record 3 of Set 11 | gazojak
# Processing Record 4 of Set 11 | suva
# Processing Record 5 of Set 11 | ta`u
# Processing Record 6 of Set 11 | nicoya
# Processing Record 7 of Set 11 | ghanzi
# Processing Record 8 of Set 11 | gulf shores
# Processing Record 9 of Set 11 | hanover
# Processing Record 10 of Set 11 | kushiro
# Processing Record 11 of Set 11 | berezovyy
# Processing Record 12 of Set 11 | acheng
# Processing Record 13 of Set 11 | bikenibeu village
# Processing Record 14 of Set 11 | remire-montjoly
# Processing Record 15 of Set 11 | robore
# Processing Record 16 of Set 11 | neon karlovasion
# Processing Record 17 of Set 11 | pama
# Processing Record 18 of Set 11 | ghazni
# Processing Record 19 of Set 11 | noumea
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | oruro
# Processing Record 22 of Set 11 | murghob
# Processing Record 23 of Set 11 | sinjai
# Processing Record 24 of Set 11 | urengoy
# Processing Record 25 of Set 11 | siwa oasis
# Processing Record 26 of Set 11 | howrah
# Processing Record 27 of Set 11 | punta del este
# Processing Record 28 of Set 11 | mananjary
# Processing Record 29 of Set 11 | pathein
# Processing Record 30 of Set 11 | musay'id
# City not found. Skipping...
# Processing Record 31 of Set 11 | suwayr
# Processing Record 32 of Set 11 | buenavista del norte
# Processing Record 33 of Set 11 | samashki
# Processing Record 34 of Set 11 | vordingborg
# Processing Record 35 of Set 11 | duba
# Processing Record 36 of Set 11 | vodice
# Processing Record 37 of Set 11 | taroudant
# Processing Record 38 of Set 11 | saipan
# Processing Record 39 of Set 11 | keflavik
# Processing Record 40 of Set 11 | shevchenkove
# Processing Record 41 of Set 11 | hasaki
# Processing Record 42 of Set 11 | sal rei
# Processing Record 43 of Set 11 | zakynthos
# Processing Record 44 of Set 11 | gulf breeze
# Processing Record 45 of Set 11 | stuttgart
# Processing Record 46 of Set 11 | biltine
# Processing Record 47 of Set 11 | lumut
# Processing Record 48 of Set 11 | katihar
# Processing Record 49 of Set 11 | seogwipo
# City not found. Skipping...
# Processing Record 0 of Set 12 | levuka
# Processing Record 1 of Set 12 | hanawa
# Processing Record 2 of Set 12 | tucano
# Processing Record 3 of Set 12 | thanh hoa
# Processing Record 4 of Set 12 | trairi
# Processing Record 5 of Set 12 | al kharj
# Processing Record 6 of Set 12 | san martin de los andes
# Processing Record 7 of Set 12 | revda
# Processing Record 8 of Set 12 | macherla
# Processing Record 9 of Set 12 | brezina
# Processing Record 10 of Set 12 | sao miguel do iguacu
# Processing Record 11 of Set 12 | weleri
# Processing Record 12 of Set 12 | chilecito
# Processing Record 13 of Set 12 | pyin oo lwin
# Processing Record 14 of Set 12 | quiberon
# Processing Record 15 of Set 12 | tezu
# Processing Record 16 of Set 12 | bay roberts
# Processing Record 17 of Set 12 | pitimbu
# Processing Record 18 of Set 12 | tukrah
# Processing Record 19 of Set 12 | ar rutbah
# Processing Record 20 of Set 12 | rondonopolis
# Processing Record 21 of Set 12 | mubende
# Processing Record 22 of Set 12 | aljezur
# Processing Record 23 of Set 12 | tura
# Processing Record 24 of Set 12 | fale old settlement
# Processing Record 25 of Set 12 | kota kinabalu
# Processing Record 26 of Set 12 | revelstoke
# Processing Record 27 of Set 12 | la huacana
# Processing Record 28 of Set 12 | chonchi
# Processing Record 29 of Set 12 | alamos
# Processing Record 30 of Set 12 | gilau
# Processing Record 31 of Set 12 | patterson
# Processing Record 32 of Set 12 | la passe
# Processing Record 33 of Set 12 | adilabad
# Processing Record 34 of Set 12 | poplar bluff
# Processing Record 35 of Set 12 | vaskelovo
# Processing Record 36 of Set 12 | pont-l'abbe
# City not found. Skipping...
# Processing Record 37 of Set 12 | benin city
# Processing Record 38 of Set 12 | kuhsan
# Processing Record 39 of Set 12 | pirallahi
# Processing Record 40 of Set 12 | klaksvik
# Processing Record 41 of Set 12 | la'ie
# Processing Record 42 of Set 12 | palembang
# Processing Record 43 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 44 of Set 12 | espargos
# City not found. Skipping...
# Processing Record 45 of Set 12 | colihaut
# City not found. Skipping...
# Processing Record 46 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 47 of Set 12 | porto velho
# Processing Record 48 of Set 12 | as sulayyil
# Processing Record 49 of Set 12 | tucurui
# Processing Record 0 of Set 13 | horizontina
# Processing Record 1 of Set 13 | hailar
# Processing Record 2 of Set 13 | qamdo
# Processing Record 3 of Set 13 | petrolina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    lautoka -17.6167  177.4667     27.92        57          40        6.69
# 1   qaqortoq  60.7167  -46.0333      5.49        89          93        2.35
# 2  rice lake  45.5061  -91.7382     22.99       100           0        0.00
# 3   hermanus -34.4187   19.2345     13.78        46          96        4.64
# 4   ishigaki  24.3448  124.1572     26.07        94          75       12.35
#
#   Country        Date
# 0      FJ  1691038376
# 1      GL  1691038376
# 2      US  1691038224
# 3      ZA  1691038377
# 4      JP  1691038378

# %%
# Export the City_Data into a csv

city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          lautoka -17.6167  177.4667     27.92        57          40
# 1         qaqortoq  60.7167  -46.0333      5.49        89          93
# 2        rice lake  45.5061  -91.7382     22.99       100           0
# 3         hermanus -34.4187   19.2345     13.78        46          96
# 4         ishigaki  24.3448  124.1572     26.07        94          75
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      FJ  1691038376
# 1              2.35      GL  1691038376
# 2              0.00      US  1691038224
# 3              4.64      ZA  1691038377
# 4             12.35      JP  1691038378

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the city weather data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a scatter plot for Latitude vs Temperature
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], color='blue', alpha=0.7)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.title("Latitude vs Max Temperature")
plt.grid(True)
plt.savefig ("output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the city weather data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a scatter plot for Latitude vs Humidity
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], color='blue', alpha=0.7)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Latitude vs Humidity")
plt.grid(True)
plt.savefig ("output_data/Fig2.png")
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the city weather data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a scatter plot for Latitude vs Cloudiness
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], color='blue', alpha=0.7)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs Cloudiness")
plt.grid(True)
plt.savefig ("output_data/Fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the city weather data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a scatter plot for Latitude vs Wind Speed
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], color='blue', alpha=0.7)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("Latitude vs Wind Speed")
plt.grid(True)
plt.savefig ("output_data/Fig4.png")
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def create_linear_regression_plot(x_values, y_values, x_label, y_label, title, output_filename):
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line's y values
    regression_values = slope * x_values + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolors="black", alpha=0.75)
    
    # Plot the regression line
    plt.plot(x_values, regression_values, "r-", label="y={:.2f}x+{:.2f}".format(slope, intercept))
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.grid(True)
    
    # Add legend
    plt.legend(loc="best")
    
    # Save the figure using the correct relative path
    output_dir = "output_data"
    
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         qaqortoq  60.7167  -46.0333      5.49        89          93
# 2        rice lake  45.5061  -91.7382     22.99       100           0
# 4         ishigaki  24.3448  124.1572     26.07        94          75
# 5        tazacorte  28.6290  -17.9293     23.54        73         100
# 7         bilibino  68.0546  166.4372     10.78        94         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.35      GL  1691038376
# 2              0.00      US  1691038224
# 4             12.35      JP  1691038378
# 5              8.23      ES  1691038379
# 7              2.51      RU  1691038380

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  lautoka -17.6167  177.4667     27.92        57          40
# 3                 hermanus -34.4187   19.2345     13.78        46          96
# 6                grytviken -54.2811  -36.5092     -0.48        95         100
# 11                coquimbo -29.9533  -71.3436     14.85        94         100
# 12       port-aux-francais -49.3500   70.2167      2.16        99         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      FJ  1691038376
# 3              4.64      ZA  1691038377
# 6              1.97      GS  1691038379
# 11             2.57      CL  1691038382
# 12            10.95      TF  1691038383

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Create a linear regression plot
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot
r_value = create_linear_regression_plot(
    northern_hemi_df["Lat"], 
    northern_hemi_df["Max Temp"], 
    "Latitude", 
    "Max Temperature (°C)", 
    "Northern Hemisphere - Max Temp vs. Latitude Linear Regression", 
    "Fig5.png"
)

# Print the r-value
print("r-value for Max Temperature vs. Latitude in Northern Hemisphere:", r_value)
# Out:
# r-value for Max Temperature vs. Latitude in Northern Hemisphere: -0.540897229816485

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Create a linear regression plot for Southern Hemisphere
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot for Southern Hemisphere
r_value_southern = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Max Temp"], 
    "Latitude", 
    "Max Temperature (°C)", 
    "Southern Hemisphere - Max Temp vs. Latitude Linear Regression", 
    "Fig6.png"
)

# Print the r-value for Southern Hemisphere
print("r-value for Max Temperature vs. Latitude in Southern Hemisphere:", r_value_southern)
# Out:
# r-value for Max Temperature vs. Latitude in Southern Hemisphere: 0.7385978153636588

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The calculated r-value for the relationship between Max Temperature and Latitude in the Southern Hemisphere is approximately 0.73. An r-value closer to 1 indicates a strong positive correlation, meaning that as Latitude increases, Max Temperature also tends to increase consistently. In this case, the r-value of 0.73 suggests a moderately strong positive correlation between Max Temperature and Latitude in the Southern Hemisphere.
#
# The positive r-value of 0.73 indicates that as you move towards lower latitudes in the Southern Hemisphere, the Max Temperature tends to rise. Other factors, such as seasonality, geographical features, and local climate patterns, may also play a role in influencing the Max Temperature at different latitudes.
#
# Overall, the r-value of 0.73 suggests a significant positive relationship between Max Temperature and Latitude in the Southern Hemisphere, but further analysis and consideration of other factors are necessary to fully understand the drivers of temperature variations across latitudes in this region.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Assuming you have already defined northern_hemi_df and imported required libraries

# Create a linear regression plot for Humidity vs. Latitude
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot for Humidity vs. Latitude in Northern Hemisphere
r_value_humidity_northern = create_linear_regression_plot(
    northern_hemi_df["Lat"], 
    northern_hemi_df["Humidity"], 
    "Latitude", 
    "Humidity (%)", 
    "Northern Hemisphere - Humidity vs. Latitude Linear Regression", 
    "Fig8.png"
)

# Print the r-value for Humidity vs. Latitude in Northern Hemisphere
print("r-value for Humidity vs. Latitude in Northern Hemisphere:", r_value_humidity_northern)
# Out:
# r-value for Humidity vs. Latitude in Northern Hemisphere: -0.09951161868224051

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Create a linear regression plot for Humidity vs. Latitude
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot for Humidity vs. Latitude in Southern Hemisphere
r_value_humidity_southern = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Humidity"], 
    "Latitude", 
    "Humidity (%)", 
    "Southern Hemisphere - Humidity vs. Latitude Linear Regression", 
    "Fig9.png"
)

# Print the r-value for Humidity vs. Latitude in Southern Hemisphere
print("r-value for Humidity vs. Latitude in Southern Hemisphere:", r_value_humidity_southern)
# Out:
# r-value for Humidity vs. Latitude in Southern Hemisphere: 0.2526207156245074

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The calculated r-value for the relationship between Humidity and Latitude in the Southern Hemisphere is approximately 0.253. An r-value closer to 1 indicates a strong positive correlation, implying that as Latitude increases, Humidity tends to increase consistently. However, in this case, the r-value of 0.253 suggests a relatively weak positive correlation between Humidity and Latitude in the Southern Hemisphere.
#
# The positive r-value of 0.253 indicates that there is a modest tendency for Humidity to increase slightly as one moves towards lower latitudes in the Southern Hemisphere. This suggests that regions closer to the equator may experience slightly higher humidity levels. However, it's important to approach this interpretation cautiously, as other influencing factors, such as local climate patterns, oceanic influences, and seasonal variations, can also significantly affect Humidity levels.
#
# While the r-value of 0.253 suggests a weak positive relationship between Humidity and Latitude in the Southern Hemisphere, it is important to note that correlation does not imply causation. This correlation coefficient implies a limited linear association and should be considered in conjunction with domain knowledge and a broader analysis of contributing factors to draw meaningful conclusions about Humidity patterns in the Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Create a linear regression plot for Cloudiness vs. Latitude
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot for Cloudiness vs. Latitude in Northern Hemisphere
r_value_cloudiness_northern = create_linear_regression_plot(
    northern_hemi_df["Lat"], 
    northern_hemi_df["Cloudiness"], 
    "Latitude", 
    "Cloudiness (%)", 
    "Northern Hemisphere - Cloudiness vs. Latitude Linear Regression", 
    "Fig10.png"
)

# Print the r-value for Cloudiness vs. Latitude in Northern Hemisphere
print("r-value for Cloudiness vs. Latitude in Northern Hemisphere:", r_value_cloudiness_northern)
# Out:
# r-value for Cloudiness vs. Latitude in Northern Hemisphere: -0.02462355198321212

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Create a linear regression plot for Cloudiness vs. Latitude
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot for Cloudiness vs. Latitude in Southern Hemisphere
r_value_cloudiness_southern = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Cloudiness"], 
    "Latitude", 
    "Cloudiness (%)", 
    "Southern Hemisphere - Cloudiness vs. Latitude Linear Regression", 
    "Fig11.png"
)

# Print the r-value for Cloudiness vs. Latitude in Southern Hemisphere
print("r-value for Cloudiness vs. Latitude in Southern Hemisphere:", r_value_cloudiness_southern)
# Out:
# r-value for Cloudiness vs. Latitude in Southern Hemisphere: -0.02119790128429223

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The calculated r-value for the relationship between Cloudiness and Latitude in the Southern Hemisphere is approximately -0.021. An r-value closer to -1 indicates a strong negative correlation, suggesting that as Latitude increases, Cloudiness tends to decrease consistently. However, in this case, the r-value of -0.021 indicates an extremely weak negative correlation between Cloudiness and Latitude in the Southern Hemisphere.
#
# The negative r-value of -0.021 suggests a marginal tendency for Cloudiness to decrease slightly as one moves towards higher latitudes in the Southern Hemisphere. This weak correlation implies that Latitude alone is not a substantial predictor of Cloudiness variations. Other factors, such as local atmospheric conditions, topographical features, and regional climate patterns, are likely more influential in determining Cloudiness levels across different latitudes.
#
# Given the minimal correlation coefficient, it is crucial to exercise caution when drawing conclusions solely based on this relationship. The r-value of -0.021 signifies that Cloudiness and Latitude have a nearly negligible linear association in the Southern Hemisphere. Interpretations should be made with consideration of other relevant variables and an understanding of broader atmospheric dynamics that affect Cloudiness patterns.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Assuming you have already defined northern_hemi_df and imported required libraries

# Create a linear regression plot for Wind Speed vs. Latitude
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot for Wind Speed vs. Latitude in Northern Hemisphere
r_value_wind_speed_northern = create_linear_regression_plot(
    northern_hemi_df["Lat"], 
    northern_hemi_df["Wind Speed"], 
    "Latitude", 
    "Wind Speed (m/s)", 
    "Northern Hemisphere - Wind Speed vs. Latitude Linear Regression", 
    "Fig12.png"
)

# Print the r-value for Wind Speed vs. Latitude in Northern Hemisphere
print("r-value for Wind Speed vs. Latitude in Northern Hemisphere:", r_value_wind_speed_northern)
# Out:
# r-value for Wind Speed vs. Latitude in Northern Hemisphere: -0.06863679838962775

# %%
import os
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Assuming you have already defined southern_hemi_df and imported required libraries

# Create a linear regression plot for Wind Speed vs. Latitude
def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, filename):
    plt.figure(figsize=(8, 6))
    plt.scatter(x_data, y_data, marker='o', color='blue', alpha=0.7)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_data, y_data)
    
    # Add regression line to the plot
    plt.plot(x_data, slope * x_data + intercept, color='red', label='Linear Regression')
    
    plt.legend()
    plt.grid(True)
    
    # Save the plot as an image
    output_dir = "output_data"

    plt.savefig(output_dir)
    plt.show()
    
    return r_value

# Call the function and create the plot for Wind Speed vs. Latitude in Southern Hemisphere
r_value_wind_speed_southern = create_linear_regression_plot(
    southern_hemi_df["Lat"], 
    southern_hemi_df["Wind Speed"], 
    "Latitude", 
    "Wind Speed (m/s)", 
    "Southern Hemisphere - Wind Speed vs. Latitude Linear Regression", 
    "Fig13.png"
)

# Print the r-value for Wind Speed vs. Latitude in Southern Hemisphere
print("r-value for Wind Speed vs. Latitude in Southern Hemisphere:", r_value_wind_speed_southern)
# Out:
# r-value for Wind Speed vs. Latitude in Southern Hemisphere: -0.32420230999308125

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The calculated r-value for the relationship between Wind Speed and Latitude in the Southern Hemisphere is approximately -0.324. An r-value closer to -1 suggests a strong negative correlation, indicating that as Latitude increases, Wind Speed tends to decrease consistently. In this case, the r-value of -0.324 indicates a moderate negative correlation between Wind Speed and Latitude in the Southern Hemisphere.
#
# The negative r-value of -0.324 implies a notable tendency for Wind Speed to decrease as one moves towards higher latitudes in the Southern Hemisphere. This correlation suggests that regions closer to the equator generally experience higher wind speeds, while areas further from the equator tend to have lower wind speeds. However, it's essential to approach this interpretation with consideration of other factors that can influence wind patterns, such as local topography, oceanic influences, and regional weather systems.
#
# The r-value of -0.324 indicates a meaningful, albeit moderate, negative relationship between Wind Speed and Latitude in the Southern Hemisphere. While latitude alone may not be the sole determinant of wind speed variations, this correlation provides valuable insights for understanding broad wind patterns in the region. To gain a comprehensive understanding of wind speed dynamics, a more detailed analysis incorporating additional meteorological factors is warranted.
